# %%
import osmnx as ox, networkx as nx, pandas as pd, geopandas as gpd, time, matplotlib.pyplot as plt, math
import re
import statsmodels.api as sm
from geopy.distance import great_circle
from shapely.geometry import Polygon
# %matplotlib inline
ox.config(use_cache=True, log_file=True, log_console=True, log_filename='calc_stats_every_us_urban_area',
          data_folder='G:/Geoff/osmnx/urbanized-areas-usa', cache_folder='G:/Geoff/osmnx/cache')

# %%
gdf = gpd.read_file('input_data/tl_2016_us_uac10').sort_values(by='ALAND10', ascending=False)
len(gdf)
# Out:
# 3601

# %%
# remove the tiny census "urban clusters" to retain only "urban areas"
gdf = gdf[~gdf['NAMELSAD10'].str.contains('Urban Cluster')]
len(gdf)
# Out:
# 497

# %%
gdf[['NAMELSAD10', 'ALAND10', 'AWATER10', 'GEOID10', 'geometry']].head()
# Out:
#                                        NAMELSAD10     ALAND10   AWATER10  \
# 2321  New York--Newark, NY--NJ--CT Urbanized Area  8937429045  532939320
# 3002                   Atlanta, GA Urbanized Area  6850045152   94712176
# 3250               Chicago, IL--IN Urbanized Area  6325255332  106765178
# 2546  Philadelphia, PA--NJ--DE--MD Urbanized Area  5132095000  127546905
# 1593            Boston, MA--NH--RI Urbanized Area  4852285339  202265876
#
#      GEOID10                                           geometry
# 2321   63217  (POLYGON ((-74.896562 40.561084, -74.896255 40...
# 3002   03817  (POLYGON ((-85.04216699999999 33.714332, -85.0...
# 3250   16264  (POLYGON ((-88.471932 42.120298, -88.472899 42...
# 2546   69076  (POLYGON ((-76.02113299999999 39.981897, -76.0...
# 1593   09271  (POLYGON ((-71.64691599999999 42.644126, -71.6...

# %%
def load_graph_get_stats(row):
    
    start_time = time.time()
    name = row['NAMELSAD10']
    geoid = row['GEOID10']
    land_area = row['ALAND10']
    name_geoid = '{}_{}'.format(row['NAMELSAD10'], row['GEOID10']).replace(',', '_').replace(' ', '_')
    
    try:
        G = ox.load_graphml('{}.graphml'.format(name_geoid))
        stats = ox.basic_stats(G, area=land_area)
        stats['name'] = name
        stats['geoid'] = geoid
        stats['area'] = land_area
        
        # unpack k-counts and k-proportion dicts into individiual keys:values
        for k, count in stats['streets_per_node_counts'].items():
            stats['int_{}_streets_count'.format(k)] = count
        for k, proportion in stats['streets_per_node_proportion'].items():
            stats['int_{}_streets_prop'.format(k)] = proportion
            
        # calculate/drop the extended stats that have values per node
        extended_stats = ox.extended_stats(G)
        se = pd.Series(extended_stats)
        se = se.drop(['avg_neighbor_degree', 'avg_weighted_neighbor_degree', 'clustering_coefficient',
                      'clustering_coefficient_weighted', 'degree_centrality', 'pagerank'])
        extended_stats_clean = se.to_dict()
        
        for key in extended_stats_clean:
            stats[key] = extended_stats_clean[key]
        
        stats['area_km'] = land_area / 1e6
        stats['time'] = time.time()-start_time
        return pd.Series(stats)

    except Exception as e:
        print('{} failed: {}'.format(name, e))

# %%
stats = gdf.apply(load_graph_get_stats, axis=1)
stats.head()
# Out:
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3133584978
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 104277311
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 104277327
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3740822215
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3740822221
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3776684061
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3139392060
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 822360497
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 822360502
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3233564876
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3163599926
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3158095663
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 4346662960
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 1296886747
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3582008699
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3295267028
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2854344148
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2854344978
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3158721053
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3237389452
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 4334200861
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3293296251
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3582008707
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3160151839
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3160349771
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3155643854
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3155643860
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3155644369
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3155644381
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3155644384
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3155644387
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2679609233
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 103792884
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3160381515
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3155643853
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3155644361
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3155644363
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3155644382
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3155644385
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3280461981
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3270682367
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2166419880
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3428077846
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 62165434
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 49258745
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 99583955
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3230986763
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3738684460
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2675915756
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3313473837
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 396128415
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 396436026
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2069366689
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 1777254099
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 181489418
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2590213659
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2590213663
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2590213665
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2590213661
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2590213691
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2590213693
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2590213694
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 4254973256
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 4354910659
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2393333257
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 4124847451
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3986411768
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3350640569
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 450708251
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3136114921
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 4284269256
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 4284269257
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3050937757
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3992874201
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3114271345
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3114271439
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3114271474
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3114271462
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3132314149
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3055738494
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2724374688
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 4079503019
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 4405236209
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 53441671
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3021386180
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 101360485
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3283337306
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2901468307
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2901283581
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2901283600
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3283342421
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2901480773
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2901480776
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2901480778
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2901480786
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2901468311
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2901282387
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 1199741418
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3132301366
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3163635417
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2207575663
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2207575692
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 4012668467
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3167637589
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3167637590
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3167637591
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3167637592
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3167637593
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3167637594
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3167637588
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3679033794
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3071213992
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3144949973
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3144949981
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3144949957
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3077729915
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 2397575828
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3470810800
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3789575032
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3802916211
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3198042970
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3198043040
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 37068829
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 147191328
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 147181528
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3729787721
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 100258130
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 402325265
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 191039567
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 47489022
#   warnings.warn('zero out-degree for node %s' % u)
# C:\Anaconda\lib\site-packages\networkx\generators\stochastic.py:56: UserWarning: zero out-degree for node 3656193019
#   warnings.warn('zero out-degree for node %s' % u)
#             area      area_km  avg_neighbor_degree_avg  \
# 2321  8937429045  8937.429045                 2.891812
# 3002  6850045152  6850.045152                 2.758075
# 3250  6325255332  6325.255332                 2.980270
# 2546  5132095000  5132.095000                 2.840241
# 1593  4852285339  4852.285339                 2.776859
#
#       avg_weighted_neighbor_degree_avg  circuity_avg  \
# 2321                          0.038259      1.060343
# 3002                          0.026858      1.098680
# 3250                          0.028692      1.065626
# 2546                          0.099789      1.080482
# 1593                          0.030162      1.089688
#
#       clustering_coefficient_avg  clustering_coefficient_weighted_avg  \
# 2321                    0.037874                             0.000260
# 3002                    0.036286                             0.000526
# 3250                    0.035814                             0.000646
# 2546                    0.048361                             0.000374
# 1593                    0.050355                             0.000591
#
#       count_intersections  degree_centrality_avg  edge_density_km  \
# 2321               307848               0.000014     15925.250512
# 3002               125948               0.000025     11463.474331
# 3250               171122               0.000027     14235.536574
# 2546               136789               0.000032     13253.791234
# 1593               117553               0.000034     11768.845380
#
#          ...       pagerank_min_node  self_loop_proportion street_density_km  \
# 2321     ...               254806534              0.007042       8844.471431
# 3002     ...                72357514              0.010281       6163.986938
# 3250     ...               367529557              0.011058       7772.813508
# 2546     ...               103809222              0.009984       7302.505354
# 1593     ...                70780317              0.023745       6435.435076
#
#       street_length_avg  street_length_total  street_segments_count  \
# 2321         148.095174         7.904684e+07                 533757
# 3002         185.660215         4.222359e+07                 227424
# 3250         163.248939         4.916503e+07                 301166
# 2546         159.192725         3.747715e+07                 235420
# 1593         153.955900         3.122657e+07                 202828
#
#       streets_per_node_avg                            streets_per_node_counts  \
# 2321              2.855058  {0: 1, 1: 65460, 2: 1466, 3: 229681, 4: 75294,...
# 3002              2.451515  {0: 0, 1: 59346, 2: 464, 3: 108342, 4: 16781, ...
# 3250              2.919495  {0: 0, 1: 34405, 2: 954, 3: 117716, 4: 51783, ...
# 2546              2.873055  {0: 0, 1: 27140, 2: 672, 3: 102796, 4: 32576, ...
# 1593              2.709323  {0: 0, 1: 30030, 2: 601, 3: 99830, 4: 16538, 5...
#
#                             streets_per_node_proportion         time
# 2321  {0: 2.6787460254105847e-06, 1: 0.1753507148233...  1327.774858
# 3002  {0: 0.0, 1: 0.32028020335251006, 2: 0.00250412...   384.065474
# 3250  {0: 0.0, 1: 0.16739893055413643, 2: 0.00464172...   419.556416
# 2546  {0: 0.0, 1: 0.16555948001878862, 2: 0.00409933...   336.567767
# 1593  {0: 0.0, 1: 0.2034787204488322, 2: 0.004072284...   271.580517
#
# [5 rows x 56 columns]

# %%
stats.to_csv('data/usa_stats.csv', encoding='utf-8', index=False)
stats['time'].sum()
# Out:
# 11414.738343954086
